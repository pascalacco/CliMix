# %%
import numpy as np
import scipy as scp
import pylab as pyl
import pandas as pd
import bokeh as bk
import bokeh.plotting as bkp
import json
import pandas_bokeh
pandas_bokeh.output_notebook()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 8
#       6 import bokeh.plotting as bkp
#       7 import json
# ----> 8 import pandas_bokeh
#       9 pandas_bokeh.output_notebook()
#
# File ~/Documents/climix_github/venv/lib/python3.10/site-packages/pandas_bokeh/__init__.py:10
#       7 from bokeh.layouts import column, layout, row
#       9 from .base import embedded_html, output_file, output_notebook, plot_grid, show
# ---> 10 from .geoplot import geoplot
#      11 from .plot import FramePlotMethods, plot
#      13 __version__ = "0.5.5"
#
# File ~/Documents/climix_github/venv/lib/python3.10/site-packages/pandas_bokeh/geoplot.py:8
#       6 from bokeh.colors import RGB
#       7 from bokeh.models import NumeralTickFormatter, TickFormatter
# ----> 8 from bokeh.tile_providers import get_provider
#      10 from .base import embedded_html
# ...

# %% [markdown]
# # Production algo éole
#
# Il faut lancer jupyter du répertoire <rep>/flaskapp sinon le impor tne marche pas.

# %%
from climix import visualiseur
import archiveur
dm = archiveur.DataManager(equipe="IMACS_A1",partie="S1")
chroniques = dm.get_chroniques(annee="2030")
resultats = dm.get_results()
chroniques.describe()
self = visualiseur.vProduction(chroniques)

# %%
#bkp.show(self.fig_prod())
composants = self.get_composants()
print(composants['divs'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 #bkp.show(self.fig_prod())
# ----> 2 composants = self.get_composants()
#       3 print(composants['divs'])
#
# File ~/Documents/climix_github/climix/visualiseur.py:90, in Visualiseur.get_composants(self)
#      89 def get_composants(self):
# ---> 90     script, divs = components(self.figs)
#      91     return {"script": script, "divs": divs}
#
# File ~/Documents/climix_github/venv/lib/python3.10/site-packages/bokeh/embed/standalone.py:265, in components(models, wrap_script, wrap_plot_info, theme)
#     262     models = list(models.values())
#     264 # 2) Append models to one document. Either pre-existing or new and render
# --> 265 with OutputDocumentFor(models, apply_theme=theme):
#     266     (docs_json, [render_item]) = standalone_docs_json_and_render_items(models)
# ...

# %%
import numpy as np

from bokeh.layouts import column
from bokeh.plotting import figure, show
from bokeh.palettes import tol

dates,source = vs.get_dates_et_source()
p,select = vs.range_fig()

colonnes = chroniques.columns.values
prod = [col for col in colonnes if ("prod" in col) and ("prodResiduelle" not in col) and ("prod_stock" not in col)]
#p.line('date', 'prodResiduelle', source=source)
p.varea_stack(stackers=prod, x='date', color=tol['Bright'][6][:len(prod)], legend_label=prod, source=source)
p.line(x='date', y='-prodResiduelle', source=source, legend_label='production résiduelle')
p.yaxis.axis_label = 'production (GW)'
p.legend.click_policy="mute"

select.line('date', '-prodResiduelle', source=source)
fig=column(p, select)

show(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 7
#       4 from bokeh.plotting import figure, show
#       5 from bokeh.palettes import tol
# ----> 7 dates,source = vs.get_dates_et_source()
#       8 p,select = vs.range_fig()
#      10 colonnes = chroniques.columns.values
#
# NameError: name 'vs' is not defined

# %%
heurespartial=chroniques.date.values
chroniques['prod_stock']=chroniques[["Gprod", "Bprod","Pprod","Lprod"]].sum(axis=1)
prod_stock=chroniques['prod_stock'].values
prod_Meth=chroniques['Gprod'].values
prod_Phs=chroniques['Pprod'].values       
prod_Lake=chroniques['Lprod'].values
prod_Battery=chroniques['Bprod'].values

# %%
import holoviews as hv
hv.extension('bokeh')
from bokeh.embed import components

hvfig = hv.Area((heurespartial,-prod_stock)).options(width=600)
fig = hv.render(hvfig)
bkp.show(fig)
script, divs = components(fig)
print(script)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
#   <div id="bc0fdcfe-bb56-421a-8360-da3f130db9b3" data-root-id="p3310" style="display: contents;"></div>
#     <script type="text/javascript">
# ...

# %%
C3=hv.Area((heurespartial,-prod_stock[d:f])).options(width=600)

A1=hv.Area((heurespartial,np.array(prod2006_offshore[d:f])*self.offshore),label='offshore')

A2=hv.Area((heurespartial,np.array(prod2006_offshore[d:f])*self.offshore\
            +np.array(prod2006_onshore[d:f])*self.onshore),label='onshore')

A3=hv.Area((heurespartial,np.array(prod2006_offshore[d:f])*self.offshore\
           +np.array(prod2006_onshore[d:f])*self.onshore\
           +np.array(prod2006_pv[d:f])*self.pv),label='photovoltaic')

A4=hv.Area((heurespartial,np.array(prod2006_offshore[d:f])*self.offshore\
           +np.array(prod2006_onshore[d:f])*self.onshore\
           +np.array(prod2006_pv[d:f])*self.pv+coefriv*rivprod[d:f]),label='river')

A5=hv.Area((heurespartial,np.array(prod2006_offshore[d:f])*self.offshore\
           +np.array(prod2006_onshore[d:f])*self.onshore\
           +np.array(prod2006_pv[d:f])*self.pv+coefriv*rivprod[d:f]+prod_Battery[d:f]),label='Battery')

A6=hv.Area((heurespartial,np.array(prod2006_offshore[d:f])*self.offshore\
           +np.array(prod2006_onshore[d:f])*self.onshore\
           +np.array(prod2006_pv[d:f])*self.pv+coefriv*rivprod[d:f]+prod_Battery[d:f]\
           +prod_Phs[d:f]),label='Decharge Phs')

A7=hv.Area((heurespartial,np.array(prod2006_offshore[d:f])*self.offshore\
           +np.array(prod2006_onshore[d:f])*self.onshore\
           +np.array(prod2006_pv[d:f])*self.pv+coefriv*rivprod[d:f]+prod_Battery[d:f]\
           +prod_Phs[d:f]+prod_Lake[d:f]),label='Lakes')

A8=hv.Area((heurespartial,np.array(prod2006_offshore[d:f])*self.offshore\
           +np.array(prod2006_onshore[d:f])*self.onshore\
           +np.array(prod2006_pv[d:f])*self.pv+coefriv*rivprod[d:f]+prod_Battery[d:f]\
           +prod_Phs[d:f]+prod_Lake[d:f]+prod_Meth[d:f]),label='Decharge Methanation')

C1=hv.Curve((heures[d:f],Conso[d:f])).options(width=900,color='black')

C2=hv.Area((heurespartial,Methanation.prod[d:f]),label='Prod Methanation').options(width=900)
#A8*A7*A6*A5*A4*A3*A2*A1*C1
return pn.Column(A8*A7*A6*A5*A4*A3*A2*A1*C1,hv.Curve((heures[d:f],prodresiduelle[d:f]),label='Residual Production')\
                 .options(width=900,color='black')*C3\
                 ,hv.Curve((heurespartial,s[d:f]),label='Overproduction').options(width=900))

# %%
import constantes
# Out:
# Sur le chemin local /home/pacco/climix_test/flaskapp/

# %% [markdown]
# # Visualisation d'un scenario
# On charge un des scénarios généré dans le notebook [scenarios](scenarios.ipynb)

# %%
scenar="S1"
mix_data = "../flaskapp/mix_data/"
fich = mix_data+scenar+"_25-50.h5"
df = pd.read_hdf(fich, "df")
print(df.describe())
print(df.sum(axis=0))
# Out:
#             demande   electrolyse
# count  52560.000000  5.256000e+04
# mean      45.982777  3.954979e+00
# std       13.432050  7.014595e+00
# min       17.852749  0.000000e+00
# 25%       35.841237  1.661394e-08
# 50%       44.764427  2.453123e-01
# 75%       54.385204  5.061730e+00
# max      105.645183  2.720755e+01
# demande        2.416855e+06
# electrolyse    2.078737e+05
# dtype: float64

# %%
df_tours =df.resample("5Y").sum().reset_index()
df_tours['date'] = df_tours['date'].apply(lambda x: x.strftime('%Y'))
df_tours.set_index(['date'], inplace=True)
print(df_tours)
print(df_tours.sum(axis=0))
# Out:
#             demande   electrolyse
# date
# 2025  464615.274146      0.000000
# 2030  439892.814026  13858.248059
# 2035  415170.353906  27716.496118
# 2040  390447.893787  41574.744177
# 2045  365725.433667  55432.992236
# 2050  341002.973547  69291.240296
# demande        2.416855e+06
# electrolyse    2.078737e+05
# dtype: float64

# %%
from bokeh.palettes import HighContrast3
annees = df_tours.index.to_list()
colonnes = df_tours.columns.to_list()
p = bkp.figure(title="Scenario")

p.vbar_stack(stackers=colonnes, x=df_tours.index.values, source=df_tours)

show(p)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 6
#       3 colonnes = df_tours.columns.to_list()
#       4 p = bkp.figure(title="Scenario")
# ----> 6 p.vbar_stack(stackers=colonnes, x=df_tours.index.values, source=df_tours)
#       8 show(p)
#
# File ~/Documents/climix_test/venv/lib/python3.8/site-packages/bokeh/plotting/_figure.py:605, in figure.vbar_stack(self, stackers, **kw)
#     603 result = []
#     604 for kw in double_stack(stackers, "bottom", "top", **kw):
# --> 605     result.append(self.vbar(**kw))
#     606 return result
#
# File ~/Documents/climix_test/venv/lib/python3.8/site-packages/bokeh/plotting/_decorators.py:87, in glyph_method.<locals>.decorator.<locals>.wrapped(self, *args, **kwargs)
#      85 if self.coordinates is not None:
#      86     kwargs.setdefault("coordinates", self.coordinates)
# ...

# %%
def cumul_plot(T, cols, palette=bk.palettes.Category10_10):
    couleurs = iter(palette)
    source = bk.models.ColumnDataSource(T)
    fig = bkp.figure()
    fig.varea_stack(stackers=cols, x="heures", color=[next(couleurs) for col in cols], legend_label=cols, source=source )
    return fig

# %%
from bokeh.palettes import HighContrast3
from bokeh.plotting import figure, show

fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
years = ["2015", "2016", "2017"]

data = {'fruits' : fruits,
        '2015'   : [2, 1, 4, 3, 2, 4],
        '2016'   : [5, 3, 4, 2, 4, 6],
        '2017'   : [3, 2, 4, 4, 5, 3]}

p = figure(x_range=fruits, height=250, title="Fruit Counts by Year",
           toolbar_location=None, tools="hover", tooltips="$name @fruits: @$name")

p.vbar_stack(years, x='fruits', width=0.9, color=HighContrast3, source=data,
             legend_label=years)

p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xgrid.grid_line_color = None
p.axis.minor_tick_line_color = None
p.outline_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "horizontal"

show(p)

Project
# Out:
#   <div id="d9dd6586-1c2c-4f12-8aea-0ffa87cc7d97" data-root-id="p1058" style="display: contents;"></div>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 28
#      24 p.legend.orientation = "horizontal"
#      26 show(p)
# ---> 28 Project
#
# NameError: name 'Project' is not defined

# %%
fig = bkp.figure()
palette=bk.palettes.Category10_10
couleurs = iter(palette)
#fig.line(x="heures", y="d2025", legend_label = "2025", color= next(couleurs), source=df)
fig = cumul_plot(df_tours,cols=)
print("année 2050");
bkp.show(fig)
# Out:
#   Cell In[7], line 5
#     fig = cumul_plot(df_tours,cols=)
#                                    ^
# SyntaxError: invalid syntax

# %%
from bokeh.layouts import column
from bokeh.models import ColumnDataSource, RangeTool
from bokeh.plotting import figure, show


dates = np.array(AAPL['date'], dtype=np.datetime64)
source = ColumnDataSource(data=dict(date=dates, close=AAPL['adj_close']))

p = figure(height=300, width=800, tools="xpan", toolbar_location=None,
           x_axis_type="datetime", x_axis_location="above",
           background_fill_color="#efefef", x_range=(dates[1500], dates[2500]))

p.line('date', 'close', source=source)
p.yaxis.axis_label = 'Price'

select = figure(title="Drag the middle and edges of the selection box to change the range above",
                height=130, width=800, y_range=p.y_range,
                x_axis_type="datetime", y_axis_type=None,
                tools="", toolbar_location=None, background_fill_color="#efefef")

range_tool = RangeTool(x_range=p.x_range)
range_tool.overlay.fill_color = "navy"
range_tool.overlay.fill_alpha = 0.2

select.line('date', 'close', source=source)
select.ygrid.grid_line_color = None
select.add_tools(range_tool)

show(column(p, select))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       2 from bokeh.models import ColumnDataSource, RangeTool
#       3 from bokeh.plotting import figure, show
# ----> 6 dates = np.array(AAPL['date'], dtype=np.datetime64)
#       7 source = ColumnDataSource(data=dict(date=dates, close=AAPL['adj_close']))
#       9 p = figure(height=300, width=800, tools="xpan", toolbar_location=None,
#      10            x_axis_type="datetime", x_axis_location="above",
#      11            background_fill_color="#efefef", x_range=(dates[1500], dates[2500]))
#
# NameError: name 'AAPL' is not defined
